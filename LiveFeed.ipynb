# %%
import cv2
import streamlink
from ultralytics import YOLO
import numpy as np

# %%
import cv2
import streamlink
from ultralytics import YOLO
import numpy as np
import time

# Funktionen för att räkna IoU (Intersection over Union) för trackingen
def iou(box1, box2):
    x1, y1, x2, y2 = box1
    x1g, y1g, x2g, y2g = box2

    xi1 = max(x1, x1g)
    yi1 = max(y1, y1g)
    xi2 = min(x2, x2g)
    yi2 = min(y2, y2g)

    inter_area = max(0, xi2 - xi1) * max(0, yi2 - yi1)
    box1_area = (x2 - x1) * (y2 - y1)
    box2_area = (x2g - x1g) * (y2g - y1g)

    union_area = box1_area + box2_area - inter_area
    return inter_area / union_area if union_area > 0 else 0

# Laddar in vår YOLO-modell
model = YOLO('./Results/train5/weights/best.pt')

# Laddar in Livestreamen, detta från Mammoth Mountain, då Levi var stängt och ingen åkte :(
youtube_url = "https://www.youtube.com/watch?v=UpfvBbw6kSY&ab_channel=MammothMountain"

#Levi nedan
#youtube_url = "https://www.youtube.com/watch?v=Wr9b5aYA4mI&ab_channel=LeviSkiResort"

# Utnyttjar Streamlink för att ta ut videon från urlen
streams = streamlink.streams(youtube_url)
if not streams or "best" not in streams:
    print("No valid stream found!")
    exit()

stream = streams["best"]
direct_stream_url = stream.url

#Öppnar Video Capture från live streamen
cap = cv2.VideoCapture(direct_stream_url)
if not cap.isOpened():
    print("Error: Could not open video stream.")
    exit()

# Objectdetektering för att räkna skidare och snowboardåkare
seen_objects = {}  
next_object_id = 0  # unikt ID
skier_count = 0
snowboarder_count = 0
TIME_THRESHOLD = 0.3  # timer som räknar 0,3 sekunder detekterad innan counter ++1

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    results = model(frame)
    current_time = time.time()
    detected_objects = []

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            confidence = box.conf[0].item()
            label = int(box.cls[0].item())  # 0 = Skidåkare, 1 = Snowboardåkare

            if confidence > 0.5:
                # Försöker matcha med ett existerande objekt baserat på IoU
                matched_id = None
                for obj_id, obj_info in seen_objects.items():
                    if iou((x1, y1, x2, y2), obj_info["bbox"]) > 0.5:
                        matched_id = obj_id
                        break

                if matched_id is None:
                    matched_id = next_object_id
                    seen_objects[matched_id] = {"timestamp": current_time, "class": label, "bbox": (x1, y1, x2, y2)}
                    next_object_id += 1

                detected_objects.append(matched_id)

                # Räknar ifall objektet finns i bild med än timer (0,3sek)
                if current_time - seen_objects[matched_id]["timestamp"] > TIME_THRESHOLD:
                    if seen_objects[matched_id]["class"] == 0:  # Skidåkare
                        skier_count += 1
                    else:  # Snowboardåkare
                        snowboarder_count += 1

                    del seen_objects[matched_id]  # radera efter räkning

                # Rita boxen
                color = (255, 0, 0) if label == 0 else (0, 0, 255)  # Röd Snowboardåkare, Blå Skidåkare

                #Skriver ut 'Skier #3' baserat på den nuvarande countern (+1 efter 0,3 sekunder i bild)
                text = f"{f'Skier #{skier_count}' if label == 0 else f'Snowboarder #{snowboarder_count}'}: {confidence:.2f}"
                
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Raderar gamla objekt som inte längre finns i bild
    seen_objects = {obj_id: obj_info for obj_id, obj_info in seen_objects.items() if obj_id in detected_objects}

    # Visa countern i mellan toppen
    cv2.putText(frame, f"Skiers: {skier_count}", (150, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    cv2.putText(frame, f"Snowboarders: {snowboarder_count}", (300, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    #Visa själva streamen
    cv2.imshow("YOLO Ski Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 72.7ms
# Speed: 2.8ms preprocess, 72.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.2ms
# Speed: 2.1ms preprocess, 56.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.8ms preprocess, 55.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.2ms preprocess, 53.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 1.1ms preprocess, 54.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 1.3ms preprocess, 52.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.3ms preprocess, 55.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 1.3ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.1ms preprocess, 53.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.2ms preprocess, 53.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.3ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.1ms
# Speed: 1.7ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 1.1ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 1.3ms preprocess, 50.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.5ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.8ms
# Speed: 2.3ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.4ms
# Speed: 1.1ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 1.4ms preprocess, 51.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 1.2ms preprocess, 55.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.1ms
# Speed: 1.5ms preprocess, 56.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.3ms preprocess, 53.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.5ms
# Speed: 1.5ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.1ms preprocess, 54.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.9ms
# Speed: 1.2ms preprocess, 50.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.6ms
# Speed: 1.3ms preprocess, 61.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.9ms
# Speed: 1.7ms preprocess, 77.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.8ms
# Speed: 1.3ms preprocess, 50.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.9ms
# Speed: 1.6ms preprocess, 58.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.2ms
# Speed: 1.2ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.6ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 1.1ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.5ms
# Speed: 1.4ms preprocess, 49.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 1.2ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 2.2ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 1.4ms preprocess, 49.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.0ms
# Speed: 1.6ms preprocess, 51.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 1.6ms preprocess, 51.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 1.1ms preprocess, 49.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.2ms preprocess, 55.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.3ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 1.1ms preprocess, 48.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.9ms
# Speed: 1.4ms preprocess, 48.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.3ms
# Speed: 1.7ms preprocess, 49.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 55.5ms
# Speed: 1.3ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 52.5ms
# Speed: 1.2ms preprocess, 52.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.1ms
# Speed: 1.3ms preprocess, 49.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.0ms
# Speed: 1.4ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.4ms
# Speed: 1.2ms preprocess, 47.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.1ms
# Speed: 1.1ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.1ms
# Speed: 1.1ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.0ms
# Speed: 1.2ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.1ms
# Speed: 1.3ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 1.3ms preprocess, 47.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 1.1ms preprocess, 47.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.7ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.3ms
# Speed: 1.1ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.3ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.1ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.4ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.3ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.4ms
# Speed: 1.3ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 44.8ms
# Speed: 1.3ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.6ms
# Speed: 1.3ms preprocess, 46.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.4ms preprocess, 45.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.1ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.4ms
# Speed: 1.4ms preprocess, 45.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.7ms
# Speed: 1.2ms preprocess, 48.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.0ms
# Speed: 1.2ms preprocess, 50.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.5ms
# Speed: 1.1ms preprocess, 47.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.9ms
# Speed: 1.3ms preprocess, 46.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.5ms
# Speed: 1.4ms preprocess, 47.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.8ms
# Speed: 1.1ms preprocess, 46.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.5ms
# Speed: 1.4ms preprocess, 46.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 52.7ms
# Speed: 1.1ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.5ms
# Speed: 1.4ms preprocess, 47.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 44.9ms
# Speed: 1.3ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.4ms
# Speed: 1.8ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.4ms
# Speed: 1.3ms preprocess, 46.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 99.2ms
# Speed: 1.1ms preprocess, 99.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.9ms
# Speed: 1.3ms preprocess, 46.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.1ms
# Speed: 1.3ms preprocess, 48.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.3ms
# Speed: 1.4ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 44.7ms
# Speed: 1.4ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.4ms
# Speed: 1.2ms preprocess, 50.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.3ms
# Speed: 1.4ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.4ms
# Speed: 1.1ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.4ms
# Speed: 1.3ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.0ms
# Speed: 1.3ms preprocess, 46.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.0ms
# Speed: 1.3ms preprocess, 46.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.5ms
# Speed: 1.3ms preprocess, 46.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.4ms
# Speed: 1.1ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.6ms
# Speed: 1.4ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.5ms
# Speed: 1.2ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.5ms
# Speed: 1.4ms preprocess, 46.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.0ms
# Speed: 1.3ms preprocess, 48.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.3ms
# Speed: 1.3ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.4ms
# Speed: 1.3ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.2ms
# Speed: 1.2ms preprocess, 45.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.3ms
# Speed: 1.1ms preprocess, 47.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.9ms
# Speed: 1.1ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.9ms
# Speed: 1.1ms preprocess, 47.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.8ms
# Speed: 1.1ms preprocess, 46.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.9ms
# Speed: 1.4ms preprocess, 47.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.2ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 51.1ms
# Speed: 1.0ms preprocess, 51.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.5ms
# Speed: 1.5ms preprocess, 48.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.9ms
# Speed: 1.3ms preprocess, 50.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.9ms
# Speed: 1.1ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.9ms
# Speed: 1.3ms preprocess, 50.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.3ms
# Speed: 1.4ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.5ms
# Speed: 1.3ms preprocess, 46.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.6ms
# Speed: 1.3ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 1.2ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 1.3ms preprocess, 48.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.3ms preprocess, 55.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.0ms
# Speed: 1.3ms preprocess, 49.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.0ms
# Speed: 1.6ms preprocess, 66.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.1ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 1.2ms preprocess, 47.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.7ms
# Speed: 1.1ms preprocess, 47.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 1.3ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.3ms preprocess, 47.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.3ms preprocess, 45.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.3ms
# Speed: 1.4ms preprocess, 47.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.4ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.5ms
# Speed: 1.4ms preprocess, 46.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 1.5ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 1.1ms preprocess, 47.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.1ms preprocess, 48.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.2ms preprocess, 53.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.1ms
# Speed: 1.2ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.4ms
# Speed: 1.3ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.0ms
# Speed: 2.1ms preprocess, 47.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.9ms
# Speed: 2.0ms preprocess, 47.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.3ms
# Speed: 1.3ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.3ms preprocess, 48.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.8ms
# Speed: 1.3ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.0ms
# Speed: 1.1ms preprocess, 48.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.4ms
# Speed: 1.2ms preprocess, 47.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 1.2ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.3ms preprocess, 46.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.4ms
# Speed: 1.5ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.1ms
# Speed: 1.1ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 1.2ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.4ms
# Speed: 1.4ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.3ms
# Speed: 1.3ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.1ms
# Speed: 1.1ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 1.4ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.2ms preprocess, 48.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 1.2ms preprocess, 47.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.7ms
# Speed: 1.1ms preprocess, 48.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.8ms
# Speed: 1.1ms preprocess, 46.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.3ms
# Speed: 1.1ms preprocess, 47.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.0ms
# Speed: 1.3ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.2ms
# Speed: 1.3ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.9ms
# Speed: 1.3ms preprocess, 47.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.5ms
# Speed: 1.2ms preprocess, 46.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 104.0ms
# Speed: 1.1ms preprocess, 104.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.0ms
# Speed: 1.3ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 60.8ms
# Speed: 1.2ms preprocess, 60.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 55.0ms
# Speed: 1.6ms preprocess, 55.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.3ms
# Speed: 1.3ms preprocess, 46.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.9ms
# Speed: 1.3ms preprocess, 46.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.4ms
# Speed: 1.4ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.1ms
# Speed: 1.1ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.0ms
# Speed: 1.2ms preprocess, 49.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.0ms
# Speed: 1.4ms preprocess, 49.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.0ms
# Speed: 1.1ms preprocess, 47.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.1ms
# Speed: 1.1ms preprocess, 48.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 45.9ms
# Speed: 1.3ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 52.8ms
# Speed: 1.3ms preprocess, 52.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.2ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 1.3ms preprocess, 45.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 1.1ms preprocess, 47.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.3ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 1.3ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 1.2ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 1.1ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 1.2ms preprocess, 49.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.4ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 1.2ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.4ms
# Speed: 1.3ms preprocess, 48.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 1.2ms preprocess, 49.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.9ms
# Speed: 1.2ms preprocess, 47.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.9ms
# Speed: 1.3ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.2ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.7ms
# Speed: 1.3ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 1.2ms preprocess, 47.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.1ms
# Speed: 1.4ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.8ms
# Speed: 1.3ms preprocess, 57.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 1.2ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.5ms
# Speed: 1.3ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 56.4ms
# Speed: 1.3ms preprocess, 56.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.3ms
# Speed: 1.2ms preprocess, 47.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 48.5ms
# Speed: 1.2ms preprocess, 48.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.4ms
# Speed: 1.4ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 1.2ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.1ms
# Speed: 1.4ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 1.3ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 47.9ms
# Speed: 1.3ms preprocess, 47.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.3ms preprocess, 47.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.2ms preprocess, 47.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.9ms
# Speed: 1.2ms preprocess, 47.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 1.3ms preprocess, 47.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# ...
# Speed: 1.5ms preprocess, 56.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 2 snowboarders, 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 47.7ms
# Speed: 1.3ms preprocess, 47.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 49.1ms
# Speed: 1.1ms preprocess, 49.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 57.6ms
# Speed: 1.4ms preprocess, 57.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 skiers, 66.5ms
# Speed: 1.5ms preprocess, 66.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 skiers, 2 snowboarders, 58.4ms
# Speed: 1.4ms preprocess, 58.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 2 snowboarders, 59.0ms
# Speed: 2.1ms preprocess, 59.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 52.0ms
# Speed: 1.1ms preprocess, 52.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 56.2ms
# Speed: 2.3ms preprocess, 56.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 skiers, 2 snowboarders, 61.3ms
# Speed: 1.2ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 skiers, 1 snowboarder, 57.6ms
# Speed: 1.7ms preprocess, 57.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 skiers, 1 snowboarder, 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 2 snowboarders, 81.1ms
# Speed: 11.2ms preprocess, 81.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 56.1ms
# Speed: 1.3ms preprocess, 56.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 2 snowboarders, 49.3ms
# Speed: 1.2ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 49.8ms
# Speed: 1.3ms preprocess, 49.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 2 snowboarders, 48.3ms
# Speed: 1.1ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 skiers, 2 snowboarders, 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 2 snowboarders, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 snowboarders, 48.7ms
# Speed: 1.2ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 skiers, 2 snowboarders, 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 skiers, 2 snowboarders, 52.5ms
# Speed: 1.3ms preprocess, 52.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 skiers, 2 snowboarders, 59.7ms
# Speed: 1.2ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 skiers, 2 snowboarders, 67.7ms
# Speed: 1.4ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 2 snowboarders, 62.3ms
# Speed: 1.4ms preprocess, 62.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 1 snowboarder, 62.0ms
# Speed: 1.7ms preprocess, 62.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 2 snowboarders, 57.0ms
# Speed: 1.5ms preprocess, 57.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 snowboarder, 48.6ms
# Speed: 1.1ms preprocess, 48.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 snowboarders, 50.0ms
# Speed: 1.3ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 snowboarders, 56.6ms
# Speed: 1.3ms preprocess, 56.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 snowboarder, 58.4ms
# Speed: 1.3ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 99.6ms
# Speed: 1.2ms preprocess, 99.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.6ms
# Speed: 1.4ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 49.3ms
# Speed: 1.5ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 50.4ms
# Speed: 1.3ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 skier, 62.6ms
# Speed: 1.3ms preprocess, 62.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 58
#      55     print("Error: Could not read frame.")
#      56     break
# ---> 58 results = model(frame)
#      59 current_time = time.time()
#      60 detected_objects = []
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\engine\model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     153 def __call__(
#     154     self,
#     155     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     156     stream: bool = False,
#     157     **kwargs: Any,
#     158 ) -> list:
#     159     """
#     160     Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
#    (...)    180         ...     print(f"Detected {len(r)} objects in image")
#     181     """
# --> 182     return self.predict(source, stream, **kwargs)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\engine\model.py:550, in Model.predict(self, source, stream, predictor, **kwargs)
#     548 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     549     self.predictor.set_prompts(prompts)
# --> 550 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\engine\predictor.py:214, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     212     return self.stream_inference(source, model, *args, **kwargs)
#     213 else:
# --> 214     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\engine\predictor.py:323, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     321 # Inference
#     322 with profilers[1]:
# --> 323     preds = self.inference(im, *args, **kwargs)
#     324     if self.args.embed:
#     325         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\engine\predictor.py:171, in BasePredictor.inference(self, im, *args, **kwargs)
#     165 """Run inference on a given image using the specified model and arguments."""
#     166 visualize = (
#     167     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     168     if self.args.visualize and (not self.source_type.tensor)
#     169     else False
#     170 )
# --> 171 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\nn\autobackend.py:568, in AutoBackend.forward(self, im, augment, visualize, embed)
#     566 # PyTorch
#     567 if self.pt or self.nn_module:
# --> 568     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     570 # TorchScript
#     571 elif self.jit:
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\nn\tasks.py:114, in BaseModel.forward(self, x, *args, **kwargs)
#     112 if isinstance(x, dict):  # for cases of training and validating while training.
#     113     return self.loss(x, *args, **kwargs)
# --> 114 return self.predict(x, *args, **kwargs)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\nn\tasks.py:132, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     130 if augment:
#     131     return self._predict_augment(x)
# --> 132 return self._predict_once(x, profile, visualize, embed)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\nn\tasks.py:153, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     151 if profile:
#     152     self._profile_one_layer(m, x, dt)
# --> 153 x = m(x)  # run
#     154 y.append(x if m.i in self.save else None)  # save output
#     155 if visualize:
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\ultralytics\nn\modules\conv.py:91, in Conv.forward_fuse(self, x)
#      81 def forward_fuse(self, x):
#      82     """
#      83     Apply convolution and activation without batch normalization.
#      84
#    (...)     89         (torch.Tensor): Output tensor.
#      90     """
# ---> 91     return self.act(self.conv(x))
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File d:\Skola\Datorseende\Skidovervakaren\venv\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
